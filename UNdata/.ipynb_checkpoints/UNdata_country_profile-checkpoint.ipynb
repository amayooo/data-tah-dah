# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
def get_value(cell):
    
    """ 
        Extract text from the element, and convert them into numbers when possible. 
        Take a cell tag.
        Return the field value.
    """
    
    text = ''.join(cell.find_all(text=True, recursive=False)).strip().replace(u'\xa0', u'')
    
    if text.replace(" ", "").isnumeric():
        return int(text.replace(" ", ""))
    
    elif text.replace(" ", "").replace(".", "").isnumeric():
        return float(text.replace(" ", ""))
    
    elif text.replace(" ", "").replace(".", "").replace("/", "").isnumeric():
        return text.replace(" ", "")
    
    else:
        return text

# %%
def get_url(country):
    
    """ 
        Find the two digit country code using a country name, based on ISO 3166-1.
        Take a country name.
        Return the url linked to the country's profile.
    """
    
    file = pd.read_csv("data_csv.csv")
    mapping = dict(zip(file["Name"].to_list(),file["Code"].to_list()))
    
    name = country.title()
    iso_code = mapping[name].lower()
    url="http://data.un.org/en/iso/"+iso_code+".html"

    return url

# %%
def general_info(soup):
    
    """ 
        Extract General Information from the UNdata database.
        Take a bs4.BeautifulSoup object generated from querying the country's profile page.
        Return a dataframe containing the country's General Information
    """
    
    tables = soup.find_all("table")
    rows = tables[1].find_all("tr")
    
    index = [[get_value(r.find_all("td")[0]) for r in rows]]
    value = [[get_value(r.find_all("td")[-1]) for r in rows]]
    
    data = dict(zip(['Index', 2019], index+value))
    
    df = pd.DataFrame(data)
    
    return df

# %%
def indicator(soup, indicator):
    
    """ 
        Extract Indicators information from the UNdata database.
        Take a bs4.BeautifulSoup object generated from querying the country's profile page
           & the name of the indicator.
        Return a dataframe containing the country's indicators data (3 years). 
    """
    
    tables = soup.find_all("table")
    
    if indicator == 'Economic indicators':
        table = tables[2]
    elif indicator == 'Social indicators':
        table = tables[3]
    elif indicator == 'Environment and infrastructure indicators':
        table = tables[4]
    
    rows = table.find_all("tr")
    col_num = len(rows[0].find_all("td"))
        
    year = [get_value(rows[0].find_all("td")[i]) for i in range(col_num)][1:] 

    col_names = ['Index','Unit']+year
    
    index = [[get_value(r.find_all("td")[0]) for r in rows[1:]]] 

    unit = [[get_value(r.find_all("td")[0].small) for r in rows[1:]]]
    
    value = [[(get_value(r.find_all("td")[i].small)) for r in rows[1:]] for i in range(-col_num+1,0)]
    
        
    data = dict(zip(col_names, index+unit+value))
    
    df = pd.DataFrame(data)
    
    return df

# %%
def get_profile(url):
    
    """ 
        Take a url that is a country's profile page.
        Return a list of two dataframes, 
               which contains the country's General Information and 
               Indicators data (3 years) respectively. 
    """
    response = requests.get(url)
    
    soup = BeautifulSoup(response.content,'lxml')

    section = [i.get_text() for i in soup.find_all("summary")]

    GI_df = general_info(soup)

    Indicators_df = pd.concat([indicator(soup, i) for i in section[1:]], keys=section[1:])

    return [GI_df, Indicators_df]

# %%
country = "CHINA"
url = get_url(country)
profile = get_profile(url)

# %%
profile[0]
# Out:
#                           Index                 2019
# 0                        Region         Eastern Asia
# 1         Population(000, 2019)              1433784
# 2   Pop. density(per km2, 2019)                152.7
# 3                  Capital city              Beijing
# 4  Capital city pop.(000, 2019)              20035.5
# 5            UN membership date            24-Oct-45
# 6             Surface area(km2)              9600000
# 7        Sex ratio(m per 100 f)                105.4
# 8             National currency  Yuan Renminbi (CNY)
# 9        Exchange rate(per US$)                  6.9

# %%
profile[1]
# Out:
#                                                                                           Index  \
# Economic indicators                       0                         GDP: Gross domestic product
#                                           1                                     GDP growth rate
#                                           2                                      GDP per capita
#                                           3                                Economy: Agriculture
#                                           4                                   Economy: Industry
#                                           5                Economy: Services and other activity
#                                           6                             Employment: Agriculture
#                                           7                                Employment: Industry
#                                           8                                Employment: Services
#                                           9                                        Unemployment
#                                           10                         Labour force participation
#                                           11                          CPI: Consumer Price Index
#                                           12                      Agricultural production index
#                                           13                       International trade: Exports
#                                           14                       International trade: Imports
#                                           15                       International trade: Balance
#                                           16               Balance of payments, current account
# Social indicators                         0                              Population growth rate
#                                           1                                    Urban population
#                                           2                        Urban population growth rate
#                                           3                               Fertility rate, total
#                                           4                            Life expectancy at birth
#                                           5                         Population age distribution
#                                           6                         International migrant stock
#                                           7             Refugees and others of concern to UNHCR
#                                           8                               Infant mortality rate
#                                           9                         Health: Current expenditure
#                                           10                                 Health: Physicians
#                                           11              Education: Primary gross enrol. ratio
#                                           12            Education: Secondary gross enrol. ratio
#                                           13             Education: Tertiary gross enrol. ratio
#                                           14                          Intentional homicide rate
#                                           15        Seats held by women in national parliaments
# Environment and infrastructure indicators 0                      Individuals using the Internet
#                                           1                  Research & Development expenditure
#                                           2                                  Threatened species
#                                           3                                       Forested area
#                                           4                              CO2 emission estimates
#                                           5                          Energy production, primary
#                                           6                            Energy supply per capita
#                                           7        Tourist/visitor arrivals at national borders
#                                           8   Important sites for terrestrial biodiversity p...
#                                           9           Net Official Development Assist. received
#
#                                                                         Unit  \
# Economic indicators                       0            (million current US$)
#                                           1   (annual %, const. 2010 prices)
#                                           2                    (current US$)
#                                           3         (% of Gross Value Added)
#                                           4         (% of Gross Value Added)
#                                           5                       (% of GVA)
#                                           6                  (% of employed)
#                                           7                  (% of employed)
#                                           8                     (% employed)
#                                           9              (% of labour force)
#                                           10            (female/male pop. %)
#                                           11                      (2010=100)
#                                           12                 (2004-2006=100)
#                                           13           (million current US$)
#                                           14           (million current US$)
#                                           15           (million current US$)
#                                           16                   (million US$)
# Social indicators                         0               (average annual %)
#                                           1          (% of total population)
#                                           2               (average annual %)
#                                           3          (live births per woman)
#                                           4           (females/males, years)
#                                           5          (0-14/60+ years old, %)
#                                           6            (000/% of total pop.)
#                                           7                            (000)
#                                           8          (per 1 000 live births)
#                                           9                       (% of GDP)
#                                           10                (per 1 000 pop.)
#                                           11              (f/m per 100 pop.)
#                                           12              (f/m per 100 pop.)
#                                           13              (f/m per 100 pop.)
#                                           14              (per 100 000 pop.)
#                                           15                             (%)
# Environment and infrastructure indicators 0            (per 100 inhabitants)
#                                           1                       (% of GDP)
#                                           2                         (number)
#                                           3                 (% of land area)
#                                           4   (million tons/tons per capita)
#                                           5                     (Petajoules)
#                                           6                     (Gigajoules)
#                                           7                            (000)
#                                           8                              (%)
#                                           9                       (% of GNI)
#
#                                                      2005         2010  \
# Economic indicators                       0       2285960      6100648
#                                           1          11.4         10.6
#                                           2        1729.7       4486.6
#                                           3            12          9.8
#                                           4          47.2         46.6
#                                           5          40.9         43.6
#                                           6          35.8         26.2
#                                           7          29.6         30.2
#                                           8          34.6         43.6
#                                           9           4.1          4.2
#                                           10    66.8/79.7    63.8/77.9
#                                           11          ...          100
#                                           12          100          120
#                                           13       761953      1577764
#                                           14       659953      1396002
#                                           15       102001       181762
#                                           16       132378       237810
# Social indicators                         0           0.6          0.6
#                                           1          42.5         49.2
#                                           2             4          3.5
#                                           3           1.6          1.6
#                                           4     74.1/70.6    75.7/71.9
#                                           5     20.4/10.8    18.7/12.2
#                                           6     678.9/0.1    849.9/0.1
#                                           7         301.1        301.1
#                                           8          27.1         18.1
#                                           9           4.1          4.2
#                                           10          1.1          1.5
#                                           11  118.6/119.2  106.6/108.2
#                                           12    60.0/63.6    88.0/88.1
#                                           13    17.9/19.8    24.8/23.3
#                                           14          1.6            1
#                                           15         20.2         21.3
# Environment and infrastructure indicators 0           8.5         34.3
#                                           1           1.3          1.7
#                                           2           773          859
#                                           3          20.6         21.4
#                                           4    5897.0/4.5   8776.0/6.5
#                                           5         63831        88642
#                                           6            53           75
#                                           7         46809        55664
#                                           8          46.6         47.1
#                                           9          0.08         0.01
#
#                                                      2019
# Economic indicators                       0      12237782
#                                           1           6.9
#                                           2        8682.2
#                                           3           8.4
#                                           4          41.3
#                                           5          50.4
#                                           6          15.5
#                                           7            26
#                                           8          58.5
#                                           9           4.8
#                                           10    60.6/75.4
#                                           11          106
#                                           12          139
#                                           13      2528426
#                                           14      2215158
#                                           15       313268
#                                           16        49092
# Social indicators                         0           0.5
#                                           1          60.3
#                                           2           2.9
#                                           3           1.6
#                                           4     77.4/73.1
#                                           5     17.8/16.8
#                                           6     999.5/0.1
#                                           7         322.4
#                                           8          12.3
#                                           9             5
#                                           10          1.8
#                                           11  102.6/101.6
#                                           12    95.9/94.2
#                                           13    56.2/46.4
#                                           14          0.6
#                                           15         24.9
# Environment and infrastructure indicators 0          54.3
#                                           1           2.1
#                                           2          1115
#                                           3          22.4
#                                           4   10291.9/7.5
#                                           5         94591
#                                           6            84
#                                           7         60740
#                                           8          47.6
#                                           9         -0.01
